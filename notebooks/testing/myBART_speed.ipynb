# %%
import warnings
warnings.filterwarnings("ignore")

from transformers import BartForConditionalGeneration, AutoTokenizer
import pandas as pd
from pathlib import Path

from src.metrics import preds_time_tps_lacc
from src.inference_utils import GenerativeModel

# %%
CURDIR = Path.cwd()

DATADIR = CURDIR / "data" / "original"
assert DATADIR.exists()

MODELS_DIR = CURDIR / "models"
assert MODELS_DIR.exists()

MODEL_ID = MODELS_DIR / 'BART_base_tune'
assert MODEL_ID.exists()

# %%
df = pd.read_csv(DATADIR / "test.csv", index_col=0, sep="\t")

df_unknown = df[df["split"] == "unknown"]
df_holdout = df[df["split"] == "holdout"]

df.shape[0], df_holdout.shape[0], df_unknown.shape[0]
# Out:
# (153991, 138882, 15109)

# %%
model = BartForConditionalGeneration.from_pretrained(MODEL_ID).to("cuda").eval()
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

# %%
gen_model = GenerativeModel(model, tokenizer)

# %%
_, elapsed_time, tps, lacc = preds_time_tps_lacc(gen_model.predict, df.head(30000))
print(f"Elapsed time: {elapsed_time:.3f} seconds")
print(f"TPS: {tps:.3f}")
print(f"lAcc: {lacc:.3f}")
print()

_, elapsed_time, tps, lacc = preds_time_tps_lacc(gen_model.predict, df_holdout.head(30000))
print(f"Elapsed time: {elapsed_time:.3f} seconds")
print(f"TPS: {tps:.3f}")
print(f"lAcc: {lacc:.3f}")
print()

_, elapsed_time, tps, lacc = preds_time_tps_lacc(gen_model.predict, df_unknown)
print(f"Elapsed time: {elapsed_time:.3f} seconds")
print(f"TPS: {tps:.3f}")
print(f"lAcc: {lacc:.3f}")
print()
# Out:
# 938it [01:35,  9.85it/s]
# Elapsed time: 95.229 seconds
# TPS: 315.031
# lAcc: 0.972
#   7%|▋         | 68/937 [00:06<01:27,  9.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 print(f"lAcc: {lacc:.3f}")
#       5 print()
# ----> 7 _, elapsed_time, tps, lacc = preds_time_tps_lacc(gen_model.predict, df_holdout.head(30000))
#       8 print(f"Elapsed time: {elapsed_time:.3f} seconds")
#       9 print(f"TPS: {tps:.3f}")
#
# File ~/sandbox/hse/DEEPlom/FasterRubic2/src/metrics.py:79, in preds_time_tps_lacc(predict_function, df)
#      75 inputs, targets = prep_inpts_targets(df)
#      77 start = time.perf_counter()
# ---> 79 preds = predict_function(inputs)
#      81 end = time.perf_counter()
#      83 elapsed_time = end - start
#
# File ~/sandbox/hse/DEEPlom/FasterRubic2/src/inference_utils/generative.py:45, in GenerativeModel.predict(self, texts, max_length, batch_size)
#      38 def predict(
#      39     self,
#      40     texts: list[str],
#      41     max_length: int = 32,
#      42     batch_size: int = 32,
#      43 ) -> list[str]:
# ---> 45     return predict(
#      46         texts=texts,
#      47         model=self.model,
#      48         tokenizer=self.tokenizer,
#      49         device=self.device,
#      50         max_length=max_length,
#      51         batch_size=batch_size,
#      52         verbose=self.verbose,
#      53     )
#
# File ~/sandbox/hse/DEEPlom/FasterRubic2/src/inference_utils/generative.py:84, in predict(texts, model, tokenizer, device, max_length, batch_size, verbose)
#      79 inputs = tokenizer(
#      80     batch, max_length=70, truncation=True, padding=True, return_tensors="pt"
#      81 ).to(device)
#      83 with torch.no_grad():
# ---> 84     outputs = model.generate(
#      85         **inputs,
#      86         max_length=max_length,
#      87         num_beams=1,
#      88         temperature=1,
#      89         early_stopping=True,
#      90     )
#      92 cur_preds = tokenizer.batch_decode(
#      93     outputs, skip_special_tokens=True, clean_up_tokenization_spaces=True
#      94 )
#      96 preds.extend(cur_preds)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:1538, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1532         raise ValueError(
#    1533             "num_return_sequences has to be 1 when doing greedy search, "
#    1534             f"but is {generation_config.num_return_sequences}."
#    1535         )
#    1537     # 11. run greedy search
# -> 1538     return self.greedy_search(
#    1539         input_ids,
#    1540         logits_processor=logits_processor,
#    1541         stopping_criteria=stopping_criteria,
#    1542         pad_token_id=generation_config.pad_token_id,
#    1543         eos_token_id=generation_config.eos_token_id,
#    1544         output_scores=generation_config.output_scores,
#    1545         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1546         synced_gpus=synced_gpus,
#    1547         streamer=streamer,
#    1548         **model_kwargs,
#    1549     )
#    1551 elif is_contrastive_search_gen_mode:
#    1552     if generation_config.num_return_sequences > 1:
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:2362, in GenerationMixin.greedy_search(self, input_ids, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2359 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2361 # forward pass to get next token
# -> 2362 outputs = self(
#    2363     **model_inputs,
#    2364     return_dict=True,
#    2365     output_attentions=output_attentions,
#    2366     output_hidden_states=output_hidden_states,
#    2367 )
#    2369 if synced_gpus and this_peer_finished:
#    2370     continue  # don't waste resources running the code we don't need
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1380, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1375     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1376         decoder_input_ids = shift_tokens_right(
#    1377             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1378         )
# -> 1380 outputs = self.model(
#    1381     input_ids,
#    1382     attention_mask=attention_mask,
#    1383     decoder_input_ids=decoder_input_ids,
#    1384     encoder_outputs=encoder_outputs,
#    1385     decoder_attention_mask=decoder_attention_mask,
#    1386     head_mask=head_mask,
#    1387     decoder_head_mask=decoder_head_mask,
#    1388     cross_attn_head_mask=cross_attn_head_mask,
#    1389     past_key_values=past_key_values,
#    1390     inputs_embeds=inputs_embeds,
#    1391     decoder_inputs_embeds=decoder_inputs_embeds,
#    1392     use_cache=use_cache,
#    1393     output_attentions=output_attentions,
#    1394     output_hidden_states=output_hidden_states,
#    1395     return_dict=return_dict,
#    1396 )
#    1398 lm_logits = self.lm_head(outputs[0])
#    1399 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1266, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1259     encoder_outputs = BaseModelOutput(
#    1260         last_hidden_state=encoder_outputs[0],
#    1261         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1262         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1263     )
#    1265 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1266 decoder_outputs = self.decoder(
#    1267     input_ids=decoder_input_ids,
#    1268     attention_mask=decoder_attention_mask,
#    1269     encoder_hidden_states=encoder_outputs[0],
#    1270     encoder_attention_mask=attention_mask,
#    1271     head_mask=decoder_head_mask,
#    1272     cross_attn_head_mask=cross_attn_head_mask,
#    1273     past_key_values=past_key_values,
#    1274     inputs_embeds=decoder_inputs_embeds,
#    1275     use_cache=use_cache,
#    1276     output_attentions=output_attentions,
#    1277     output_hidden_states=output_hidden_states,
#    1278     return_dict=return_dict,
#    1279 )
#    1281 if not return_dict:
#    1282     return decoder_outputs + encoder_outputs
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1124, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1113     layer_outputs = torch.utils.checkpoint.checkpoint(
#    1114         create_custom_forward(decoder_layer),
#    1115         hidden_states,
#    (...)
#    1121         None,
#    1122     )
#    1123 else:
# -> 1124     layer_outputs = decoder_layer(
#    1125         hidden_states,
#    1126         attention_mask=attention_mask,
#    1127         encoder_hidden_states=encoder_hidden_states,
#    1128         encoder_attention_mask=encoder_attention_mask,
#    1129         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1130         cross_attn_layer_head_mask=(
#    1131             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1132         ),
#    1133         past_key_value=past_key_value,
#    1134         output_attentions=output_attentions,
#    1135         use_cache=use_cache,
#    1136     )
#    1137 hidden_states = layer_outputs[0]
#    1139 if use_cache:
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:427, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     425 self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
#     426 # add present self-attn cache to positions 1,2 of present_key_value tuple
# --> 427 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     428     hidden_states=hidden_states,
#     429     past_key_value=self_attn_past_key_value,
#     430     attention_mask=attention_mask,
#     431     layer_head_mask=layer_head_mask,
#     432     output_attentions=output_attentions,
#     433 )
#     434 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     435 hidden_states = residual + hidden_states
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:193, in BartAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     190 bsz, tgt_len, _ = hidden_states.size()
#     192 # get query proj
# --> 193 query_states = self.q_proj(hidden_states) * self.scaling
#     194 # get key, value proj
#     195 # `past_key_value[0].shape[2] == key_value_states.shape[1]`
#     196 # is checking that the `sequence_length` of the `past_key_value` is the same as
#     197 # the provided `key_value_states` to support prefix tuning
#     198 if (
#     199     is_cross_attention
#     200     and past_key_value is not None
#     201     and past_key_value[0].shape[2] == key_value_states.shape[1]
#     202 ):
#     203     # reuse k,v, cross_attentions
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/sandbox/hse/DEEPlom/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
